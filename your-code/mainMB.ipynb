# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# Your Code Here

# %%
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'

                                                                   
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('../data/Fitbit2.csv')
fitbit.info()
fitbit.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        367 non-null    object
#  1   Calorie burned              367 non-null    int64
#  2   Steps                       367 non-null    int64
#  3   Distance                    367 non-null    float64
#  4   Floors                      367 non-null    int64
#  5   Minutes Sedentary           367 non-null    float64
#  6   Minutes Lightly Active      367 non-null    int64
#  7   Minutes Fairly Active       367 non-null    int64
#  8   Minutes Very Active         367 non-null    int64
#  9   Activity Calories           367 non-null    int64
#  10  MinutesOfSleep              367 non-null    int64
#  11  MinutesOfBeingAwake         367 non-null    int64
#  12  NumberOfAwakings            367 non-null    int64
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
# your code here
fitbit_t1 = pd.DataFrame(fitbit["Steps"].groupby(fitbit["Months_encoded"]).mean())
monthlist = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
plot_1 = sns.barplot(x = monthlist , y = 'Steps',data = fitbit_t1, palette = "Greens_d")
plot_1.set(xlabel='Month', ylabel='Average monthly steps')

plt.savefig('stepsmonth.png')

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here
fitbit_t2 = pd.DataFrame(fitbit["Steps"].groupby(fitbit["Work_or_Weekend"]).mean())
plot_2 = sns.barplot(x = fitbit['Work_or_Weekend'], y = 'Steps',data = fitbit_t2, palette = "Reds_r")
plt.savefig('Stepsworkweek.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
titanic = pd.read_csv('../data/titanic.csv')

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('/mnt/c/Users/34687/documents/github/lab-matplotlib-seaborn/data/titanic.csv')
titanic.sample(3)
# Out:
#      PassengerId  Survived  Pclass  \
# 586          587       0.0       2
# 507          508       1.0       1
# 820          821       1.0       1
#
#                                                   Name  Gender        Age  \
# 586                            Jarvis, Mr. John Denzil    male  47.000000
# 507      Bradley, Mr. George ("George Arthur Brayton")    male  46.260826
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.000000
#
#      SibSp  Parch  Ticket   Fare Cabin Embarked
# 586      0      0  237565  15.00    U0        S
# 507      0      0  111427  26.55    U0        S
# 820      1      1   12749  93.50   B69        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include='number', exclude=None).sample(5)
# Out:
#       PassengerId  Survived  Pclass       Age  SibSp  Parch      Fare
# 210           211       0.0       3  24.00000      0      0    7.0500
# 384           385       0.0       3  27.82418      0      0    7.8958
# 426           427       1.0       2  28.00000      1      0   26.0000
# 1266         1267       NaN       1  45.00000      0      0  262.3750
# 1058         1059       NaN       3  18.00000      2      2   34.3750

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include='object', exclude=None).sample(5)
# Out:
#                                                    Name  Gender  \
# 446                   Mellinger, Miss. Madeleine Violet  female
# 1234  Cardeza, Mrs. James Warburton Martinez (Charlo...  female
# 259                         Parrish, Mrs. (Lutie Davis)  female
# 1177             Franklin, Mr. Charles (Charles Fardon)    male
# 1111                     Duran y More, Miss. Florentina  female
#
#                   Ticket        Cabin Embarked
# 446               250644           U0        S
# 1234            PC 17755  B51 B53 B55        C
# 259               230433           U0        S
# 1177  SOTON/O.Q. 3101314           U0        S
# 1111       SC/PARIS 2148           U0        C

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
sns.set_style('dark')
sns.set(rc={'figure.figsize':(12,6)})
#De la lista de stilos ,tras value error con 'classic', eligo dark, 
#error : style must be one of white, dark, whitegrid, darkgrid, ticks

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
sns.histplot( x="Age", data=titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12,6))

sns.histplot(data = "titanic", x = titanic.Age, bins=10, ax=axs[0])
sns.histplot(data = "titanic", x = titanic.Age, bins=20, ax=axs[1])
sns.histplot(data = "titanic", x = titanic.Age, bins =50, ax=axs[2])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
El aumento del bin, origina modificaciones leves, el valor maximo de Y disminuye con el aumento del bin mientras que
X aumenta el numero de observaciones.
"""
# Out:
# '\nEl aumento del bin, origina modificaciones leves, el valor maximo de Y disminuye con el aumento del bin mientras que\nX aumenta el numero de observaciones.\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.histplot( x="Age", data=titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
titanic.groupby(["Gender"])["Gender"].count().plot(kind="bar");
plt.xticks(rotation=45)
# Out:
# (array([0, 1]), [Text(0, 0, 'female'), Text(1, 0, 'male')])

# %%
# Method 2 - seaborn
# your code here
sns.countplot(x="Gender", data=titanic, palette="BuGn");

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.countplot(x="Pclass", data=titanic, palette="BuGn");

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
graf = sns.histplot(x=titanic.Age, kde=True)

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
graf1 = sns.histplot(x=titanic.Age, kde=True) 
graf1.axvline(x=titanic.Age.mean(), c="red", label="mean")
graf1.axvline(x=titanic.Age.median(), c="green", label="median")
plt.legend();

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(x=titanic.Age, y=titanic.Fare)

# %%
# Method 2 - seaborn
# your code here
sns.scatterplot(x="Age", y="Fare", data=titanic)
#sns.regplot(x="Age", y="Fare", data=titanic)
plt.ylim(-1,200) #me genera la linea de tendencia y el intervalo de confianza a ambos lados de esta
# Out:
# (-1.0, 200.0)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
corr = titanic.corr()
corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Pclass and fare
"""
# Out:
# '\nPclass and fare\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.pairplot(titanic, hue="Pclass") #tarda un poco en ejecutarse

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
g = sns.FacetGrid(titanic, col="Gender")
g.map_dataframe(sns.histplot, x="Age")
